# %% [markdown]
# <a href="https://colab.research.google.com/github/Divya-sri7/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Divya-sri7/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My lane (or freestyle) and why
#
# I chose the Content Refresh lane because it focuses on identifying pages that may need updating based on their performance metrics. This can help prioritize pages for review. The starter dataset provides page-level information that makes this a useful question to explore over the coming weeks.

# %%
print("Lane selected: Content Refresh")# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Lane selected: Content Refresh

# %% [markdown]
# ## The question
#
# **Decision:** Decide which pages should be reviewed or refreshed first.
#
# **Action:** Prioritize pages that show signs of lower performance for further review.
#
# **Cost of a wrong recommendation:** If the recommendation is incorrect, time may be spent updating pages that do not need changes while important pages are overlooked.

# %%
print("Research question defined.")# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Research question defined.

# %% [markdown]
# ## Quick look at the data
#
# The starter dataset contains approximately 30,000 pages. The average CTR provides an overall view of page engagement. The correlation between search_volume and impressions_90d is approximately 0.001, indicating little linear relationship between these two variables in this dataset. These observations suggest that multiple factors may influence page performance and support further analysis in this lane.

# %%
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Correlation between search_volume and impressions_90d:",
      round(df["search_volume"].corr(df["impressions_90d"]), 3))
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Total pages: 30000
# Average CTR: 0.511
# Correlation between search_volume and impressions_90d: 0.001

# %% [markdown]
# ## Careful words
#
# The findings in this notebook are observations based on the provided starter dataset. They are intended to support decision-making by identifying patterns and trends. They do not establish cause-and-effect relationships and should not be interpreted as general conclusions beyond this dataset.

# %%
print("Careful language confirmed.")# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Careful language confirmed.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
